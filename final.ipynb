# %% [markdown]
# <a href="https://colab.research.google.com/github/unjelly27/hwsw-project-/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone "https://github.com/unjelly27/hwsw-project-.git"
# Out:
# Cloning into 'hwsw-project-'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 27 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 13.33 MiB | 23.96 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# !ls
# Out:
# hwsw-project-  sample_data

# %%
# %cd hwsw-project-
# Out:
# /content/hwsw-project-

# %%
# !pwd
# Out:
# /content/hwsw-project-

# %%
# !python evaluate.py

# %%
# Clone repo
# !git clone https://github.com/unjelly27/hwsw-project-.git
# %cd hwsw-project-
# Out:
# Cloning into 'hwsw-project-'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 27 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 13.33 MiB | 24.96 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/hwsw-project-/hwsw-project-

# %%
# Run project
# !python evaluate.py
